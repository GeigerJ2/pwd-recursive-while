# %% [markdown]
# # Python

# %% [markdown]
# ## Basic while loop

# %%
x=0
limit = 5

while x < limit:
    x +=1

print(x)
# Out:
# 5

# %% [markdown]
# ## Recursive

# %%
def while_loop(x, limit):
    if not (x < limit):
        return x
    x += 1
    return while_loop(x=x, limit=limit)

while_loop(limit=5, x=0)
# Out:
# 5

# %% [markdown]
# ## Functional

# %%
def condition(x, limit):
    return limit > x

# %%
def function_body(x):
    return x + 1

# %%
def abstract_while(x, limit):
    if not condition(x=x, limit=limit):
        return x
    x = function_body(x=x)
    return abstract_while(x=x, limit=limit)

# %%
abstract_while(x=0, limit=5)
# Out:
# 5

# %% [markdown]
# # Workflow Manager

# %% [markdown]
# ## Aiida workgraph

# %%
from aiida_workgraph import task
from aiida import load_profile
load_profile()
# Out:
# Profile<uuid='843792b66e7e4825af3e60ccac480418' name='pwd'>

# %%
def condition(x, limit):
    return limit > x

# %%
@task
def function_body(x):
    return x + 1

# %%
@task.graph
def abstract_while(x, limit):
    if not condition(x=x, limit=limit):
        return x
    x = function_body(x=x).result
    return abstract_while(x=x, limit=limit)

# %%
wg = abstract_while.build(x=0, limit=5)
wg.run()
# Out:
# 10/21/2025 09:06:49 PM <179> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|continue_workgraph]: tasks ready to run: function_body
# 10/21/2025 09:06:50 PM <179> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|update_task_state]: Task: function_body, type: PYFUNCTION, finished.
# 10/21/2025 09:06:50 PM <179> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|continue_workgraph]: tasks ready to run: abstract_while
# 10/21/2025 09:06:50 PM <179> plumpy.processes: [ERROR] Error in task abstract_while: Cannot convert value of type <class 'aiida_workgraph.sockets.builtins.SocketAny'> to AiiDA type.
# Traceback (most recent call last):
#   File "/srv/conda/envs/notebook/lib/python3.12/site-packages/aiida_workgraph/engine/task_manager.py", line 216, in execute_process_task
#     process, state = task.execute(
#                      ^^^^^^^^^^^^^
#   File "/srv/conda/envs/notebook/lib/python3.12/site-packages/aiida_workgraph/tasks/graph_task.py", line 55, in execute
#     wg = materialize_graph(
#          ^^^^^^^^^^^^^^^^^^
#   File "/srv/conda/envs/notebook/lib/python3.12/site-packages/node_graph/utils/graph.py", line 168, in materialize_graph
#     raw = func(**inputs)
#           ^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_179/3355960686.py", line 6, in abstract_while
#     return abstract_while(x=x, limit=limit)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_179/3308915236.py", line 2, in abstract_while
#     if not condition(x=x, limit=limit):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_179/3378432144.py", line 2, in condition
#     return limit > x
#            ^^^^^^^^^
#   File "/srv/conda/envs/notebook/lib/python3.12/site-packages/aiida/orm/nodes/data/numeric.py", line 26, in inner
#     return to_aiida_type(func(left, right))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/srv/conda/envs/notebook/lib/python3.12/functools.py", line 912, in wrapper
#     return dispatch(args[0].__class__)(*args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/srv/conda/envs/notebook/lib/python3.12/site-packages/aiida/orm/nodes/data/base.py", line 24, in to_aiida_type
#     raise TypeError(f'Cannot convert value of type {type(value)} to AiiDA type.')
# TypeError: Cannot convert value of type <class 'aiida_workgraph.sockets.builtins.SocketAny'> to AiiDA type.
#
# 10/21/2025 09:06:50 PM <179> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|on_task_failed]: Task, abstract_while, type: GRAPH, failed.
# 10/21/2025 09:06:50 PM <179> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|run_error_handlers]: Run error handlers for abstract_while
# 10/21/2025 09:06:50 PM <179> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|is_workgraph_finished]: WorkGraph finished, but tasks: ['abstract_while'] failed. Thus all their child tasks are skipped.
# {}

# %% [markdown]
# ## jobflow

# %%
from jobflow import job, Flow, Response
from jobflow.managers.local import run_locally

# %%
def condition(x, limit):
    return limit > x

# %%
def function_body(x):
    return x + 1

# %%
@job
def abstract_while(x, limit):
    if not condition(x, limit): 
        return x
    x = function_body(x)
    job_obj = abstract_while(x=x, limit=limit)
    return Response(replace=job_obj, output=job_obj.output)

# %%
flow = Flow([abstract_while(limit=5, x=0)])
run_locally(flow)
# Out:
# 2025-10-21 21:06:50,920 INFO Started executing jobs locally
# 2025-10-21 21:06:51,121 INFO Starting job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7)
# 2025-10-21 21:06:51,123 INFO Finished job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7)
# 2025-10-21 21:06:51,124 INFO Starting job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 2)
# 2025-10-21 21:06:51,125 INFO Finished job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 2)
# 2025-10-21 21:06:51,125 INFO Starting job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 3)
# 2025-10-21 21:06:51,126 INFO Finished job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 3)
# 2025-10-21 21:06:51,127 INFO Starting job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 4)
# 2025-10-21 21:06:51,128 INFO Finished job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 4)
# 2025-10-21 21:06:51,129 INFO Starting job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 5)
# 2025-10-21 21:06:51,130 INFO Finished job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 5)
# 2025-10-21 21:06:51,130 INFO Starting job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 6)
# 2025-10-21 21:06:51,132 INFO Finished job - abstract_while (b29dec41-d37d-4cfb-9c93-a1dffcb09cb7, 6)
# 2025-10-21 21:06:51,133 INFO Finished executing jobs locally
# {'b29dec41-d37d-4cfb-9c93-a1dffcb09cb7': {1: Response(output=OutputReference(b29dec41-d37d-4cfb-9c93-a1dffcb09cb7), detour=None, addition=None, replace=Flow(name='Flow', uuid='fbaf80f0-1df7-4bf5-9de0-2f2fd17c4d8f')
#   1. Job(name='abstract_while', uuid='b29dec41-d37d-4cfb-9c93-a1dffcb09cb7'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   2: Response(output=OutputReference(b29dec41-d37d-4cfb-9c93-a1dffcb09cb7), detour=None, addition=None, replace=Flow(name='Flow', uuid='97c363f7-e115-43b8-89a2-3964dc51a967')
#   1. Job(name='abstract_while', uuid='b29dec41-d37d-4cfb-9c93-a1dffcb09cb7'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   3: Response(output=OutputReference(b29dec41-d37d-4cfb-9c93-a1dffcb09cb7), detour=None, addition=None, replace=Flow(name='Flow', uuid='4b1a0c46-3728-4662-8de1-0f0470eb0332')
#   1. Job(name='abstract_while', uuid='b29dec41-d37d-4cfb-9c93-a1dffcb09cb7'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   4: Response(output=OutputReference(b29dec41-d37d-4cfb-9c93-a1dffcb09cb7), detour=None, addition=None, replace=Flow(name='Flow', uuid='3ef98854-4310-4d30-8317-bb4d8a4edc02')
#   1. Job(name='abstract_while', uuid='b29dec41-d37d-4cfb-9c93-a1dffcb09cb7'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   5: Response(output=OutputReference(b29dec41-d37d-4cfb-9c93-a1dffcb09cb7), detour=None, addition=None, replace=Flow(name='Flow', uuid='cf9455e8-a8f2-4f0c-add2-ed98493fadf0')
#   1. Job(name='abstract_while', uuid='b29dec41-d37d-4cfb-9c93-a1dffcb09cb7'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   6: Response(output=5, detour=None, addition=None, replace=None, stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan'))}}

# %% [markdown]
# ## pyiron_base

# %%
from pyiron_base import job, Project

# %%
def condition(x, limit):
    return limit > x

# %%
@job
def function_body(x):
    return x + 1

# %%
# internal function
def while_generator(condition, function_body):
    def abstract_while(x, limit, pyiron_project=Project(".")):
        if not condition(x=x, limit=limit):
            return x
        x = function_body(x=x, pyiron_project=pyiron_project).pull()
        return abstract_while(x=x, limit=limit, pyiron_project=pyiron_project)

    return abstract_while

# %%
pr = Project("test")
pr.remove_jobs(recursive=True, silently=True)
# Out:
# 0it [00:00, ?it/s]

# %%
while_generator(condition=condition, function_body=function_body)(x=0, limit=5, pyiron_project=pr)
# Out:
# The job function_body_22fe092ee8c05b103ea1dd8cd57b603c was saved and received the ID: 1
# The job function_body_0f4f6df822da6a6f04b8395467657bcc was saved and received the ID: 2
# The job function_body_b1f9a2ea87658f57059d78a1a0368663 was saved and received the ID: 3
# The job function_body_efaaa22b1b57e349af45c64dd0ef749d was saved and received the ID: 4
# The job function_body_0b694a991ff7d973644d5ee70b7c8142 was saved and received the ID: 5
# 5

# %% [markdown]
# # Abstract Syntax Tree

# %%
from ast import dump, parse

# %%
while_code = """\
x = 0 
while x < 5:
    x += 1
"""

# %%
print(dump(parse(while_code), indent=4))
# Out:
# Module(
#     body=[
#         Assign(
#             targets=[
#                 Name(id='x', ctx=Store())],
#             value=Constant(value=0)),
#         While(
#             test=Compare(
#                 left=Name(id='x', ctx=Load()),
#                 ops=[
#                     Lt()],
#                 comparators=[
#                     Constant(value=5)]),
#             body=[
#                 AugAssign(
#                     target=Name(id='x', ctx=Store()),
#                     op=Add(),
#                     value=Constant(value=1))],
#             orelse=[])],
#     type_ignores=[])
