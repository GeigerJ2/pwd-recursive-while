# %% [markdown]
# # Python

# %% [markdown]
# ## Basic while loop

# %%
x=0
limit = 5

while x < limit:
    x +=1

print(x)
# Out:
# 5

# %% [markdown]
# ## Recursive

# %%
def while_loop(x, limit):
    if not (x < limit):
        return x
    x += 1
    return while_loop(x=x, limit=limit)

while_loop(limit=5, x=0)
# Out:
# 5

# %% [markdown]
# ## Functional

# %%
def condition(x, limit):
    return limit > x

# %%
def function_body(x):
    return x + 1

# %%
def abstract_while(x, limit):
    if not condition(x=x, limit=limit):
        return x
    x = function_body(x=x)
    return abstract_while(x=x, limit=limit)

# %%
abstract_while(x=0, limit=5)
# Out:
# 5

# %% [markdown]
# # Workflow Manager

# %% [markdown]
# ## Aiida workgraph

# %%
from aiida_workgraph import task
from aiida import load_profile
load_profile()
# Out:
# Profile<uuid='086d70cb198644ebb34609fa1ed264b7' name='pwd'>

# %%
def condition(x, limit):
    return limit > x

# %%
@task
def function_body(x):
    return x + 1

# %%
@task.graph
def abstract_while_aiida(x, limit):
    if not condition(x=x, limit=limit):
        # if not limit > x:
        return x
    x = function_body(x=x).result
    return abstract_while_aiida(x=x, limit=limit)

# %%
wg = abstract_while_aiida.build(x=0, limit=5)
wg.run()
# Out:
# 10/22/2025 03:27:57 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|continue_workgraph]: tasks ready to run: function_body
# 10/22/2025 03:27:57 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|update_task_state]: Task: function_body, type: PYFUNCTION, finished.
# 10/22/2025 03:27:57 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|continue_workgraph]: tasks ready to run: abstract_while_aiida
# 10/22/2025 03:27:58 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|on_wait]: Process status: Waiting for child processes: 6
# 10/22/2025 03:27:58 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [6|WorkGraphEngine|continue_workgraph]: tasks ready to run: function_body
# 10/22/2025 03:27:58 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [6|WorkGraphEngine|update_task_state]: Task: function_body, type: PYFUNCTION, finished.
# 10/22/2025 03:27:58 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [6|WorkGraphEngine|continue_workgraph]: tasks ready to run: abstract_while_aiida
# 10/22/2025 03:27:59 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [6|WorkGraphEngine|on_wait]: Process status: Waiting for child processes: 9
# 10/22/2025 03:27:59 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [9|WorkGraphEngine|continue_workgraph]: tasks ready to run: function_body
# 10/22/2025 03:27:59 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [9|WorkGraphEngine|update_task_state]: Task: function_body, type: PYFUNCTION, finished.
# 10/22/2025 03:27:59 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [9|WorkGraphEngine|continue_workgraph]: tasks ready to run: abstract_while_aiida
# 10/22/2025 03:28:00 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [9|WorkGraphEngine|on_wait]: Process status: Waiting for child processes: 12
# 10/22/2025 03:28:00 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [12|WorkGraphEngine|continue_workgraph]: tasks ready to run: function_body
# 10/22/2025 03:28:00 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [12|WorkGraphEngine|update_task_state]: Task: function_body, type: PYFUNCTION, finished.
# 10/22/2025 03:28:00 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [12|WorkGraphEngine|continue_workgraph]: tasks ready to run: abstract_while_aiida
# 10/22/2025 03:28:00 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [12|WorkGraphEngine|on_wait]: Process status: Waiting for child processes: 15
# 10/22/2025 03:28:01 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [15|WorkGraphEngine|continue_workgraph]: tasks ready to run: function_body
# 10/22/2025 03:28:01 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [15|WorkGraphEngine|update_task_state]: Task: function_body, type: PYFUNCTION, finished.
# 10/22/2025 03:28:01 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [15|WorkGraphEngine|continue_workgraph]: tasks ready to run: abstract_while_aiida
# 10/22/2025 03:28:01 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [15|WorkGraphEngine|on_wait]: Process status: Waiting for child processes: 18
# 10/22/2025 03:28:02 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [18|WorkGraphEngine|continue_workgraph]: tasks ready to run:
# 10/22/2025 03:28:02 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [18|WorkGraphEngine|finalize]: Finalize workgraph.
# 10/22/2025 03:28:02 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [15|WorkGraphEngine|update_task_state]: Task: abstract_while_aiida, type: GRAPH, finished.
# 10/22/2025 03:28:03 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [15|WorkGraphEngine|continue_workgraph]: tasks ready to run:
# 10/22/2025 03:28:03 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [15|WorkGraphEngine|finalize]: Finalize workgraph.
# 10/22/2025 03:28:03 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [12|WorkGraphEngine|update_task_state]: Task: abstract_while_aiida, type: GRAPH, finished.
# 10/22/2025 03:28:03 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [12|WorkGraphEngine|continue_workgraph]: tasks ready to run:
# 10/22/2025 03:28:03 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [12|WorkGraphEngine|finalize]: Finalize workgraph.
# 10/22/2025 03:28:03 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [9|WorkGraphEngine|update_task_state]: Task: abstract_while_aiida, type: GRAPH, finished.
# 10/22/2025 03:28:03 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [9|WorkGraphEngine|continue_workgraph]: tasks ready to run:
# 10/22/2025 03:28:03 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [9|WorkGraphEngine|finalize]: Finalize workgraph.
# 10/22/2025 03:28:04 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [6|WorkGraphEngine|update_task_state]: Task: abstract_while_aiida, type: GRAPH, finished.
# 10/22/2025 03:28:04 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [6|WorkGraphEngine|continue_workgraph]: tasks ready to run:
# 10/22/2025 03:28:04 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [6|WorkGraphEngine|finalize]: Finalize workgraph.
# 10/22/2025 03:28:05 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|update_task_state]: Task: abstract_while_aiida, type: GRAPH, finished.
# 10/22/2025 03:28:05 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|continue_workgraph]: tasks ready to run:
# 10/22/2025 03:28:05 AM <100> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [3|WorkGraphEngine|finalize]: Finalize workgraph.
# {'result': <Int: uuid: df123be2-c25f-4d4c-8b28-6e8c692b7e3f (pk: 17) value: 5>}

# %% [markdown]
# ## jobflow

# %%
from jobflow import job, Flow, Response
from jobflow.managers.local import run_locally

# %%
def condition(x, limit):
    return limit > x

# %%
def function_body(x):
    return x + 1

# %%
@job
def abstract_while_jobflow(x, limit):
    if not condition(x, limit): 
        return x
    x = function_body(x)
    job_obj = abstract_while_jobflow(x=x, limit=limit)
    return Response(replace=job_obj, output=job_obj.output)

# %%
flow = Flow([abstract_while_jobflow(limit=5, x=0)])
run_locally(flow)
# Out:
# 2025-10-22 03:28:06,229 INFO Started executing jobs locally
# 2025-10-22 03:28:06,492 INFO Starting job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f)
# 2025-10-22 03:28:06,494 INFO Finished job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f)
# 2025-10-22 03:28:06,495 INFO Starting job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 2)
# 2025-10-22 03:28:06,496 INFO Finished job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 2)
# 2025-10-22 03:28:06,497 INFO Starting job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 3)
# 2025-10-22 03:28:06,498 INFO Finished job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 3)
# 2025-10-22 03:28:06,498 INFO Starting job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 4)
# 2025-10-22 03:28:06,499 INFO Finished job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 4)
# 2025-10-22 03:28:06,500 INFO Starting job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 5)
# 2025-10-22 03:28:06,501 INFO Finished job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 5)
# 2025-10-22 03:28:06,502 INFO Starting job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 6)
# 2025-10-22 03:28:06,504 INFO Finished job - abstract_while_jobflow (c3076712-2ba3-42d6-b95f-8114d9df440f, 6)
# 2025-10-22 03:28:06,507 INFO Finished executing jobs locally
# {'c3076712-2ba3-42d6-b95f-8114d9df440f': {1: Response(output=OutputReference(c3076712-2ba3-42d6-b95f-8114d9df440f), detour=None, addition=None, replace=Flow(name='Flow', uuid='ab1426c4-f5ca-457d-b862-06420486e4e0')
#   1. Job(name='abstract_while_jobflow', uuid='c3076712-2ba3-42d6-b95f-8114d9df440f'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   2: Response(output=OutputReference(c3076712-2ba3-42d6-b95f-8114d9df440f), detour=None, addition=None, replace=Flow(name='Flow', uuid='8d1e656e-a405-4379-92e6-b76de0ce8d10')
#   1. Job(name='abstract_while_jobflow', uuid='c3076712-2ba3-42d6-b95f-8114d9df440f'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   3: Response(output=OutputReference(c3076712-2ba3-42d6-b95f-8114d9df440f), detour=None, addition=None, replace=Flow(name='Flow', uuid='33af5a51-18f4-43cc-9515-5e5df5b960b4')
#   1. Job(name='abstract_while_jobflow', uuid='c3076712-2ba3-42d6-b95f-8114d9df440f'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   4: Response(output=OutputReference(c3076712-2ba3-42d6-b95f-8114d9df440f), detour=None, addition=None, replace=Flow(name='Flow', uuid='ac44bc23-5a91-4ac6-bdbf-03c0f57bdcc2')
#   1. Job(name='abstract_while_jobflow', uuid='c3076712-2ba3-42d6-b95f-8114d9df440f'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   5: Response(output=OutputReference(c3076712-2ba3-42d6-b95f-8114d9df440f), detour=None, addition=None, replace=Flow(name='Flow', uuid='f97c0421-621d-45fd-aa9d-419ff3cdb2c3')
#   1. Job(name='abstract_while_jobflow', uuid='c3076712-2ba3-42d6-b95f-8114d9df440f'), stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan')),
#   6: Response(output=5, detour=None, addition=None, replace=None, stored_data=None, stop_children=False, stop_jobflow=False, job_dir=PosixPath('/home/jovyan'))}}

# %% [markdown]
# ## pyiron_base

# %%
from pyiron_base import job, Project

# %%
def condition(x, limit):
    return limit > x

# %%
@job
def function_body(x):
    return x + 1

# %%
# internal function
def while_generator(condition, function_body):
    def abstract_while_pyiron(x, limit, pyiron_project=Project(".")):
        if not condition(x=x, limit=limit):
            return x
        x = function_body(x=x, pyiron_project=pyiron_project).pull()
        return abstract_while_pyiron(x=x, limit=limit, pyiron_project=pyiron_project)

    return abstract_while_pyiron

# %%
pr = Project("test")
pr.remove_jobs(recursive=True, silently=True)
# Out:
# 0it [00:00, ?it/s]

# %%
while_generator(condition=condition, function_body=function_body)(x=0, limit=5, pyiron_project=pr)
# Out:
# The job function_body_22fe092ee8c05b103ea1dd8cd57b603c was saved and received the ID: 1
# The job function_body_0f4f6df822da6a6f04b8395467657bcc was saved and received the ID: 2
# The job function_body_b1f9a2ea87658f57059d78a1a0368663 was saved and received the ID: 3
# The job function_body_efaaa22b1b57e349af45c64dd0ef749d was saved and received the ID: 4
# The job function_body_0b694a991ff7d973644d5ee70b7c8142 was saved and received the ID: 5
# 5

# %% [markdown]
# # Abstract Syntax Tree

# %%
from ast import dump, parse

# %%
while_code = """\
x = 0 
while x < 5:
    x += 1
"""

# %%
print(dump(parse(while_code), indent=4))
# Out:
# Module(
#     body=[
#         Assign(
#             targets=[
#                 Name(id='x', ctx=Store())],
#             value=Constant(value=0)),
#         While(
#             test=Compare(
#                 left=Name(id='x', ctx=Load()),
#                 ops=[
#                     Lt()],
#                 comparators=[
#                     Constant(value=5)]),
#             body=[
#                 AugAssign(
#                     target=Name(id='x', ctx=Store()),
#                     op=Add(),
#                     value=Constant(value=1))],
#             orelse=[])],
#     type_ignores=[])
